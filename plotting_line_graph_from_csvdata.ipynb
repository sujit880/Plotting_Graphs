# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_dir = f"./data/"

# %%
baffle_dir = f'./data/test_data/baffle/'
fedrl_dir = f'./data/test_data/FedRLChain/'

# %%
x=[]
y=[]

# %%
fed_client1 = f'{fedrl_dir}client1/{"CartPole-v0_30_08_2022-00_26_55_finished"}.csv'
fed_client2 = f'{fedrl_dir}client2/{"CartPole-v0_30_08_2022-01_38_44_finished"}.csv'
fed_client3 = f'{fedrl_dir}client3/{"CartPole-v0_30_08_2022-01_38_44_finished_1"}.csv'
fed_client4 = f'{fedrl_dir}client4/{"CartPole-v0_30_08_2022-01_18_56_finished"}.csv'
fed_client5 = f'{fedrl_dir}client5/{"CartPole-v0_30_08_2022-01_38_44_finished"}.csv'
datas = [fed_client1,fed_client2,fed_client3,fed_client4,fed_client5]

# %%
plt.figure(figsize=[25,9])
plt.grid()
for data in datas:
    df = pd.read_csv(data)
    df.drop(["tr","up"],axis=1, inplace=True)
    df
    x.append(df["epoch"].values)
    y.append(df["reward"].values)
    x1,y1 = df["epoch"].values, df["reward"].values
    plt.plot(x1,y1,linewidth=1.5)
plt.legend(["C1","C2","C3"], loc = "lower right" )
plt.show()

# %%
plt.show()

# %%
def find_argmax(datas: list):
    index,max = 0,0
    for i in range(len(datas)):
        print(i,len(datas[i]))
        if len(datas[i])> max:
            max = len(datas[i])            
            index = i
    return index

# %%
index = find_argmax(x)
# Out:
# 0 420
# 1 461
# 2 420
# 3 461
# 4 415
# 5 420
# 6 461
# 7 415
# 8 420
# 9 461
# 10 415
# 11 420
# 12 461
# 13 415
# 14 420
# 15 461
# 16 415
# 17 420
# 18 461
# 19 415
# 20 420
# 21 461
# 22 415
# 23 420
# 24 461
# 25 415
# 26 420
# 27 461
# 28 415
# 29 420
# 30 461
# 31 415
# 32 420
# 33 461
# 34 415
# 35 420
# 36 461
# 37 415
# 38 420
# 39 461
# 40 415
# 41 420
# 42 461
# 43 415
# 44 420
# 45 461
# 46 415

# %%
index
# Out:
# 1
